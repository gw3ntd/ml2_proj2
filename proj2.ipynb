# %%
import tensorflow as tf
import keras
import numpy as np
from customlayer import MyLayerNorm

# %%
# Load the dataset
(X_train_all, y_train_all), (X_test, y_test) = keras.datasets.cifar10.load_data()

X_valid, y_valid = X_train_all[-5000:], y_train_all[-5000:]
X_train, y_train = X_train_all[:-5000], y_train_all[:-5000]

# %%
X_train = (X_train / 255.)
X_valid = (X_valid / 255.) 
X_test = (X_test / 255.)

# %%
X_train.shape
# Out:
# (45000, 32, 32, 3)

# %%
X_train[0:32]

# %%
layernorm = tf.keras.layers.LayerNormalization(axis=[1, 2, 3])

sample1 = X_train[0:32]
norm_values1 = layernorm(sample1)

sample2 = X_train[1:2]
norm_values2 = layernorm(sample2)


print(norm_values1.shape)
print(norm_values2.shape)

print(norm_values1)
# Out:
# (32, 32, 32, 3)
# (1, 32, 32, 3)
# tf.Tensor(
# [[[[-0.84507644 -0.7880374  -0.76902443]
#    [-1.1492847  -1.0922457  -1.1112586 ]
#    [-1.0161936  -1.0542196  -1.1492847 ]
#    ...
#    [ 1.0372119   0.5428735   0.0865612 ]
#    [ 0.9231338   0.40978244 -0.02751688]
#    [ 0.8470817   0.39076942 -0.00850387]]
#
#   [[-1.662636   -1.586584   -1.586584  ]
#    [-1.9668443  -1.9668443  -1.9668443 ]
#    [-1.6246101  -1.8147402  -1.9668443 ]
#    ...
#    [ 0.3717564  -0.2936991  -0.9211285 ]
#    [ 0.29570433 -0.38876414 -1.0161936 ]
#    [ 0.3527434  -0.31271207 -0.8831025 ]]
#
#   [[-1.491519   -1.5105319  -1.5675709 ]
#    [-1.662636   -1.8337532  -1.9668443 ]
#    [-1.0352066  -1.4534929  -1.8147402 ]
#    ...
#    [ 0.27669135 -0.36975113 -1.0161936 ]
#    [ 0.31471735 -0.36975113 -1.0161936 ]
#    [ 0.10557421 -0.57889426 -1.1682976 ]]
#
#   ...
#
#   [[ 1.9878626   1.265368   -0.14159496]
#    [ 1.8547715   0.94214684 -1.3204018 ]
#    [ 1.7977325   1.0942509  -1.4725059 ]
#    ...
#    [ 1.0752379   0.56188655 -0.63593334]
#    [-0.9021155  -1.3774408  -1.8337532 ]
#    [-0.95915455 -1.3204018  -1.586584  ]]
#
#   [[ 1.4554982   0.6759646  -0.14159496]
#    [ 1.3224071   0.3717564  -1.1682976 ]
#    [ 1.5695763   0.7710297  -1.3964539 ]
#    ...
#    [ 1.5315503   0.8470817  -0.179621  ]
#    [-0.12258195 -0.7880374  -1.3204018 ]
#    [-0.38876414 -0.95915455 -1.3204018 ]]
#
#   [[ 1.3984592   0.7710297   0.23866531]
#    [ 1.227342    0.48583448 -0.179621  ]
#    [ 1.4364852   0.7330037  -0.31271207]
#    ...
#    [ 2.1399667   1.5315503   0.69497764]
#    [ 0.9041208   0.27669135 -0.36975113]
#    [ 0.53457224  0.52007306  0.52007306]
#    [ 0.50557387  0.49107468  0.49107468]
#    [ 0.47657552  0.46207634  0.46207634]]
#
#   [[ 1.7235048   1.8104999   1.7525032 ]
#    [ 1.6800072   1.7670023   1.7090056 ]
#    [ 1.7235048   1.8104999   1.7525032 ]
#    ...
#    [ 0.53457224  0.52007306  0.57806975]
#    [ 0.50557387  0.49107468  0.54907143]
#    [ 0.44757715  0.44757715  0.50557387]]
#
#   ...
#
#   [[-0.6833587  -0.7558546  -0.9588431 ]
#    [-0.8138513  -0.8863472  -1.1473324 ]
#    [-0.784853   -0.8428497  -1.1763308 ]
#    ...
#    [-1.277825   -1.3793192  -1.4663143 ]
#    [-1.3068234  -1.4083176  -1.4953127 ]
#    [-1.3503209  -1.4663143  -1.5533094 ]]
#
#   [[-0.65436035 -0.6833587  -0.92984474]
#    [-0.6978579  -0.7703538  -1.0168399 ]
#    [-0.7558546  -0.8428497  -1.118334  ]
#    ...
#    [-1.1473324  -1.277825   -1.4083176 ]
#    [-1.3793192  -1.4808135  -1.5823077 ]
#    [-1.4808135  -1.5823077  -1.683802  ]]
#
#   [[-0.66885954 -0.66885954 -0.91534555]
#    [-0.66885954 -0.71235704 -0.9443439 ]
#    [-0.7558546  -0.85734886 -1.0748365 ]
#    ...
#    [-1.2488266  -1.3938184  -1.5388103 ]
#    [-1.4228168  -1.5243111  -1.6548036 ]
#    [-1.5098119  -1.6113061  -1.7128004 ]]]], shape=(32, 32, 32, 3), dtype=float32)

# %%
new1 = tf.reshape(norm_values1, [-1])

# %%
new2 = tf.reshape(norm_values2, [-1])

# %%
diff = tf.subtract(new1, new2)

# %%
mean = tf.reduce_mean(diff)

# %%
print(mean)

# %%
layernorm = MyLayerNorm()

sample = X_train[:1]
norm_values = layernorm(sample)

print(norm_values)

# %%
print(np.mean(norm_values[0]))
print(np.std(norm_values[0]))

# %%
layer = tf.keras.layers.LayerNormalization()

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Input(shape=[32, 32, 3]))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(100, activation="relu"))
model.add(layer)
model.add(tf.keras.layers.Dense(10, activation="softmax"))

# %%
flatten = tf.keras.layers.Flatten()
hidden_layer1 = tf.keras.layers.Dense(100, activation="relu")
layernorm = tf.keras.layers.LayerNormalization()
output = tf.keras.layers.Dense(10, activation="softmax")

# %%
input_ = tf.keras.layers.Input(shape=[32, 32, 3])
flattened = flatten(input_)
hidden1 = hidden_layer1(flattened)
normed = layernorm(hidden1)
outputs = output(normed)

# %%
model = tf.keras.Model(inputs=[input_], outputs=[outputs])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

# %%
history = model.fit(
        X_train, y_train, 
        epochs=10,
        validation_data=(X_valid, y_valid), 
        batch_size=128
    )

# %%
print(outputs)

# %%
print(layer.beta.shape)
print(layer.gamma.shape)

# %%
print(layer.beta)

# %%
print(layer.gamma)
