# %%
import tensorflow as tf
import keras
import numpy as np
import pandas as pd
from customlayer import MyLayerNorm
import matplotlib.pyplot as plt

# %%
(X_train_images, train_labels), (X_test_images, test_labels) = tf.keras.datasets.fashion_mnist.load_data()

# %%
X_valid, y_valid = X_train_images[-5000:], train_labels[-5000:]
X_train, y_train = X_train_images[:-5000], train_labels[:-5000]

# %%
X_train = (X_train / 255.)
X_valid = (X_valid / 255.) 
X_test = (X_test_images / 255.)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    MyLayerNorm(),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 798us/step - accuracy: 0.7883 - loss: 0.6003
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 813us/step - accuracy: 0.8667 - loss: 0.3652
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 792us/step - accuracy: 0.8792 - loss: 0.3292
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.8896 - loss: 0.3042
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 923us/step - accuracy: 0.8954 - loss: 0.2811
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.8990 - loss: 0.2695
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 792us/step - accuracy: 0.9022 - loss: 0.2574
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 823us/step - accuracy: 0.9082 - loss: 0.2454
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.9108 - loss: 0.2395
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.9165 - loss: 0.2236
