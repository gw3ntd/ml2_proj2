# %%
import tensorflow as tf
import keras
import numpy as np
import pandas as pd
from customlayer import MyLayerNorm
import matplotlib.pyplot as plt

# %%
(X_train_images, train_labels), (X_test_images, test_labels) = tf.keras.datasets.fashion_mnist.load_data()

# %%
X_valid, y_valid = X_train_images[-5000:], train_labels[-5000:]
X_train, y_train = X_train_images[:-5000], train_labels[:-5000]

# %%
X_train = (X_train / 255.)
X_valid = (X_valid / 255.) 
X_test = (X_test_images / 255.)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    MyLayerNorm(),
    tf.keras.layers.Dense(10)
])
# Out:
# /Users/josephhorzempa/anaconda3/envs/math474/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 777us/step - accuracy: 0.7918 - loss: 0.5884
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 803us/step - accuracy: 0.8643 - loss: 0.3713
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 797us/step - accuracy: 0.8776 - loss: 0.3271
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 797us/step - accuracy: 0.8850 - loss: 0.3077
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.8922 - loss: 0.2880
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 822us/step - accuracy: 0.8968 - loss: 0.2706
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 799us/step - accuracy: 0.9020 - loss: 0.2581
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 956us/step - accuracy: 0.9072 - loss: 0.2494
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 809us/step - accuracy: 0.9122 - loss: 0.2354
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.9133 - loss: 0.2289

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.LayerNormalization(),
    tf.keras.layers.Dense(10)
])

# %%
model2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model2.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 833us/step - accuracy: 0.7860 - loss: 0.6030
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.8665 - loss: 0.3685
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 768us/step - accuracy: 0.8793 - loss: 0.3295
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.8902 - loss: 0.2951
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - accuracy: 0.8962 - loss: 0.2826
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 755us/step - accuracy: 0.8981 - loss: 0.2682
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.9030 - loss: 0.2614
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 749us/step - accuracy: 0.9085 - loss: 0.2392
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - accuracy: 0.9133 - loss: 0.2317
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.9145 - loss: 0.2250
