# %%
import tensorflow as tf
import keras
import numpy as np
import pandas as pd
from customlayer import MyLayerNorm
from functions import get_keras_vals, get_custom_vals, comp_layer
import matplotlib.pyplot as plt

# %%
test = tf.random.uniform(shape=[3200, 1000], minval=-100., maxval=100.)

# %%
df = comp_layer(test)

# %%
df[0]

# %%
plt.plot(df[0], label="L2 Norm", color="orange")
plt.plot(df[1], label="L INF Norm", color="green")
plt.plot(df[2], label="MSE", color="purple")
plt.title("Comparison Between Keras LayerNormalization and Custom LayerNormalization")
plt.xlabel("Batch Index")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
plt.plot(df[0])
plt.title("Numerical Difference Between Keras LayerNormalization and Custom LayerNormalization")
plt.xlabel("Batch Index")
plt.ylabel("Value")
plt.show()

# %%
plt.plot(df[1], color='orange')
plt.title("L2 Norm of Difference Between Keras LayerNormalization and Custom LayerNormalization")
plt.xlabel("Batch Index")
plt.ylabel("Value")
plt.show()

# %%
plt.plot(df[2], color='green')
plt.title("Difference Between Keras LayerNormalization L Inf Norm and Custom LayerNormalization")
plt.xlabel("Batch Index")
plt.ylabel("Value")
plt.show()
